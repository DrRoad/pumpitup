# %% [markdown]
# # Pump it Up: Data Mining the Water Table
#
# By: [Ville Heilala](https://heila.la), 2017
#
# Datasource: http://taarifa.org/, http://maji.go.tz/, https://www.drivendata.org
#
# Goal is to predict the operating condition of a waterpoint for each record in the dataset.
#
# ## Model the data

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import sys
# %matplotlib inline

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.6.0 |Anaconda 4.3.1 (64-bit)| (default, Dec 23 2016, 12:22:00)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# Pandas version 0.19.2
# Matplotlib version 2.0.0

# %%
######################
# Read data
##################################################################

train_values = pd.read_csv("/train_values_processed.csv")
test_values = pd.read_csv("/test_values_processed.csv")

# %%
exclude = ("id", "test", "train", "status_group", "num_private", "scheme_name",
           'waterpoint_type_group',
           'quality_group',
           'payment_type',
           'extraction_type_group',
           'extraction_type_class',
           'management_group',
           'source_type',
           'source_class')

# %%
from sklearn.ensemble import RandomForestClassifier

######################
# Select features
##################################################################

# Select all features except which start with a string in exclude
features = [col for col in list(train_values) if not col.startswith(exclude)]

######################
# Train model
##################################################################

# Build a forest of trees from the training set
clf = RandomForestClassifier(n_estimators=500, 
                             min_samples_leaf=2, 
                             max_features=0.20, 
                             oob_score=True, 
                             random_state=20).fit(train_values[features],
                                                  train_values["status_group"])

######################
# Evaluate model
##################################################################

print("OOB Error Score: " + str(round(1 - clf.oob_score_, 4)))
# Out:
# OOB Error Score: 0.183

# %% [markdown]
# ## Evaluate model

# %%
from sklearn.model_selection import cross_val_score

# Make prediction
predicted = clf.predict(train_values[features])

# Confusion matrix
pd.crosstab(train_values.status_group, predicted, rownames=['Actual'], colnames=['Predicted'])

# Sorted feature importance
fi = sorted(list(zip(train_values[features], clf.feature_importances_)), key=lambda x: str(x[1]), reverse=True)
fi

# Evaluate a score by cross-validation
#scores = cross_val_score(clf, train_values[features], train_values["status_group"], cv=10)
#print("Accuracy: %0.4f (+/- %0.4f)" % (scores.mean(), scores.std() * 2))
# Out:
# Predicted                functional  functional needs repair  non functional
# Actual
# functional                    31541                      177             541
# functional needs repair        1273                     2713             331
# non functional                 1660                      103           21061
# [('funder_lam', 9.9847791249815839e-05),
#  ('funder_coc', 9.9442787509889603e-05),
#  ('construction_year_1969', 9.8523406598226515e-05),
#  ('funder_the', 9.8277219660590533e-05),
#  ('funder_isl', 9.676052706341612e-05),
#  ('funder_twe', 9.4010752390927572e-05),
#  ('funder_nat', 9.3324312704433842e-05),
#  ('funder_ta', 9.231920554152226e-05),
#  ('funder_fat', 9.188937733179473e-05),
#  ('funder_co', 9.1856472413304055e-05),
#  ('funder_dmd', 8.6293744039828184e-05),
#  ('extraction_type_other - play pump', 8.4860888936473839e-05),
#  ('lga_Kilindi', 8.3568312347856547e-05),
#  ('lga_Makete', 8.2992827366966585e-05),
#  ('lga_Sikonge', 8.2558650757924901e-05),
#  ('funder_tz ', 8.1642084648540556e-06),
#  ('installer_ces', 7.9985864573313279e-05),
#  ('funder_chu', 7.9344766730652552e-05),
#  ('source_unknown', 7.7737447803173928e-05),
#  ('funder_caf', 7.7495509298127938e-06),
#  ('funder_dad', 7.691730529000074e-05),
#  ('funder_is', 7.6374265853008754e-05),
#  ('funder_ser', 7.5493862854838039e-05),
#  ('lga_Bukoba Urban', 7.438863008732767e-05),
#  ('construction_year_1968', 7.4115282708752111e-05),
#  ('funder_adp', 7.3677960210063025e-05),
#  ('district_code_63', 7.338757677655205e-05),
#  ('scheme_management_SWC', 7.3200984136634453e-05),
#  ('district_code_60', 7.2443002046746166e-05),
#  ('funder_los', 7.2019712814132277e-06),
#  ('funder_ki', 7.0676090621107622e-05),
#  ('funder_wan', 6.9620475237288935e-05),
#  ('funder_ces', 6.9470502269534487e-05),
#  ('lga_Tabora Urban', 6.853234258882096e-05),
#  ('funder_shi', 6.4138468213236657e-05),
#  ('funder_ru', 6.2746374028256296e-05),
#  ('funder_jbg', 6.2593177159460606e-05),
#  ('funder_jap', 6.2084797757613845e-05),
#  ('funder_sem', 6.0103046148610429e-05),
#  ('funder_gru', 6.0004542664396482e-05),
#  ('lga_Temeke', 5.9410915975585266e-05),
#  ('lga_Morogoro Urban', 5.9295076014340202e-05),
#  ('funder_tlc', 5.8816612194187475e-05),
#  ('funder_lvi', 5.8702316906287048e-05),
#  ('funder_sha', 5.8395612897904187e-05),
#  ('funder_sab', 5.8388065194842747e-05),
#  ('construction_year_1960', 5.8160146095551203e-05),
#  ('management_other - school', 5.6937175326338741e-05),
#  ('district_code_67', 5.5077449024410029e-06),
#  ('lga_Nanyumbu', 5.4980080085558213e-05),
#  ('loc_clust_32', 5.4587361207443416e-05),
#  ('district_code_0', 5.3836752376949023e-05),
#  ('funder_cms', 5.1769354983118792e-05),
#  ('funder_mdr', 5.1390220401542632e-05),
#  ('funder_vwc', 5.1041809585200116e-05),
#  ('lga_Mtwara Urban', 5.1033197074533136e-05),
#  ('funder_kib', 5.0741878919788364e-05),
#  ('funder_rc', 5.031564236629533e-05),
#  ('lga_Tandahimba', 5.0048568733073758e-05),
#  ('funder_md', 4.9817547010668147e-05),
#  ('construction_year_1965', 4.8938954683327492e-06),
#  ('lga_Arusha Urban', 4.8885178118535238e-05),
#  ('funder_rid', 4.7835247002062242e-05),
#  ('funder_iri', 4.6600667281810591e-05),
#  ('funder_dev', 4.6430176856288879e-05),
#  ('funder_pet', 4.6325324700794993e-05),
#  ('construction_year_1962', 4.5503981298645716e-05),
#  ('funder_par', 4.2689665344310595e-05),
#  ('lga_Ludewa', 4.265193527554185e-05),
#  ('funder_ang', 4.1099028520084224e-05),
#  ('district_code_62', 4.0497002842798874e-05),
#  ('funder_mag', 3.8914657774251497e-05),
#  ('funder_son', 3.8571369639592088e-05),
#  ('lga_Kinondoni', 3.8410621856066606e-05),
#  ('lga_Moshi Urban', 3.8364834479045848e-05),
#  ('funder_eur', 3.8110830705412701e-05),
#  ('funder_swi', 3.7358308367743677e-05),
#  ('funder_wua', 3.6006220835892759e-05),
#  ('funder_ms', 3.5763430074383783e-05),
#  ('construction_year_1964', 3.5128405802062322e-05),
#  ('funder_tar', 3.4743505787880704e-05),
#  ('water_quality_fluoride abandoned', 3.4476159627413206e-06),
#  ('lga_Liwale', 3.2701228496229781e-05),
#  ('funder_tdf', 3.2447457232750179e-05),
#  ('construction_year_1961', 2.9130433404522846e-05),
#  ('lga_Lindi Urban', 2.8101210148720744e-06),
#  ('funder_gen', 2.6059594395420175e-05),
#  ('funder_dfi', 2.5746834896171567e-05),
#  ('funder_muw', 2.1947078625801059e-05),
#  ('funder_mak', 2.1135513416807722e-05),
#  ('funder_aba', 1.8601594206681042e-05),
#  ('funder_fw', 1.8014615811945769e-05),
#  ('funder_kal', 1.7873219791475039e-05),
#  ('construction_year_1966', 1.7513191107684595e-05),
#  ('funder_chi', 1.6647171822038932e-05),
#  ('lga_Kigoma Urban', 1.6529357310248284e-05),
#  ('funder_acr', 1.6096043585090775e-07),
#  ('funder_tab', 1.5696787544473774e-05),
#  ('funder_miz', 1.4896369217551711e-06),
#  ('funder_sod', 1.4701792322888717e-06),
#  ('funder_tre', 1.3867469557979716e-05),
#  ('funder_idc', 1.3841189664850557e-05),
#  ('waterpoint_type_dam', 1.3438998629010828e-05),
#  ('lga_Songea Urban', 1.3285186949464533e-05),
#  ('loc_clust_31', 1.2252583958842098e-05),
#  ('funder_st', 1.2021935318520097e-05),
#  ('extraction_type_climax', 1.1346494613041484e-05),
#  ('district_code_80', 1.1126030849361129e-05),
#  ('funder_cef', 1.0712946203635531e-05),
#  ('funder_cdt', 1.0581813043534918e-05),
#  ('longitude', 0.085117224764915705),
#  ('latitude', 0.083716090237259413),
#  ('gps_height', 0.07505184560270424),
#  ('quantity_dry', 0.0635472995822986),
#  ('quantity_group_dry', 0.060997042636539066),
#  ('waterpoint_type_other', 0.045708575676292232),
#  ('extraction_type_other', 0.032547062176955681),
#  ('population', 0.032197773322971274),
#  ('amount_tsh', 0.020909490438702657),
#  ('quantity_enough', 0.01489817338321207),
#  ('quantity_group_enough', 0.013884418372329625),
#  ('waterpoint_type_communal standpipe multiple', 0.011663363758441684),
#  ('payment_never pay', 0.011062299906612668),
#  ('waterpoint_type_communal standpipe', 0.010444663558789152),
#  ('funder_gov', 0.0089595214105731933),
#  ('extraction_type_gravity', 0.0071123768588207438),
#  ('waterpoint_type_hand pump', 0.0067463294498769323),
#  ('source_spring', 0.006687901688103526),
#  ('quantity_group_insufficient', 0.0065660379624416154),
#  ('quantity_insufficient', 0.0062321761580936483),
#  ('extraction_type_nira/tanira', 0.0059102962331945043),
#  ('installer_dwe', 0.005657356254150727),
#  ('management_vwc', 0.0054456497107770287),
#  ('installer_installer_oth', 0.0053570846333533834),
#  ('payment_pay per bucket', 0.0047081383240621501),
#  ('source_machine dbh', 0.0046389207543308221),
#  ('source_shallow well', 0.0044750577110907264),
#  ('quantity_group_seasonal', 0.0044594152252567659),
#  ('source_rainwater harvesting', 0.0042273568253879098),
#  ('subvillage_subvillage_oth', 0.0041258655309435706),
#  ('extraction_type_ksb', 0.0040975854349922765),
#  ('scheme_management_VWC', 0.0040315207057213124),
#  ('permit_True', 0.0039660936083130895),
#  ('region_Iringa', 0.0039310153036739431),
#  ('public_meeting_True', 0.0039199120048344395),
#  ('permit_False', 0.0039144578092694835),
#  ('water_quality_soft', 0.0038602697156938032),
#  ('payment_unknown', 0.0038294208411047081),
#  ('water_quality_unknown', 0.0038168471219807302),
#  ('public_meeting_False', 0.0037662328341805064),
#  ('source_river', 0.0037097681083705504),
#  ('region_code_11', 0.0037095624418434872),
#  ('funder_funder_oth', 0.0035992288151351906),
#  ('installer_rwe', 0.0035204281131208087),
#  ('payment_pay monthly', 0.0032544425913646011),
#  ('quantity_seasonal', 0.0032486890077130935),
#  ('loc_clust_-1', 0.003033428561887712),
#  ('district_code_1', 0.0029331561345877833),
#  ('extraction_type_submersible', 0.0028096980592288391),
#  ('district_code_3', 0.0027706131655545977),
#  ('lga_Bariadi', 0.0027026403279016165),
#  ('construction_year_2010', 0.0026800351992431019),
#  ('extraction_type_swn 80', 0.002674888591776337),
#  ('district_code_2', 0.002641475727205478),
#  ('construction_year_0', 0.0025779614062709051),
#  ('funder_wor', 0.0025751987070676595),
#  ('loc_clust_7', 0.002461308054431492),
#  ('basin_Lake Nyasa', 0.0024451283545319467),
#  ('extraction_type_mono', 0.0024320902361291675),
#  ('installer_gov', 0.0024199701829190263),
#  ('basin_Internal', 0.0023618252546665471),
#  ('water_quality_salty', 0.0023330362635322036),
#  ('district_code_4', 0.0022689422610370335),
#  ('public_meeting_nan', 0.0020954934620712393),
#  ('funder_dws', 0.0020856763865763741),
#  ('management_private operator', 0.0020246206101247962),
#  ('scheme_management_WUG', 0.0019710399443858078),
#  ('basin_Lake Rukwa', 0.0019576652598552748),
#  ('construction_year_2008', 0.0019277989260841988),
#  ('construction_year_2009', 0.0018881235841794229),
#  ('funder_hes', 0.001849040693162825),
#  ('waterpoint_type_improved spring', 0.0018107145259750248),
#  ('lga_Kahama', 0.0018024259418052491),
#  ('construction_year_2006', 0.001785314050959503),
#  ('scheme_management_Water Board', 0.0017850685856822905),
#  ('source_lake', 0.0017637216884078652),
#  ('scheme_management_nan', 0.0017587670106738013),
#  ('management_wug', 0.0017413305007787465),
#  ('loc_clust_8', 0.0017127979377133532),
#  ('payment_pay when scheme fails', 0.001689208476943538),
#  ('extraction_type_india mark ii', 0.0016836372541310571),
#  ('construction_year_2007', 0.0016271954493955226),
#  ('scheme_management_Water authority', 0.0016246264511876329),
#  ('funder_dan', 0.001572309454758709),
#  ('basin_Lake Tanganyika', 0.0015518341978417545),
#  ('basin_Pangani', 0.0015470092606848509),
#  ('region_Kigoma', 0.0015390556728561843),
#  ('extraction_type_afridev', 0.0015286824393825496),
#  ('construction_year_2000', 0.0015136668117847691),
#  ('loc_clust_4', 0.0015020107633059393),
#  ('loc_clust_5', 0.0014633374591305768),
#  ('district_code_7', 0.0014622208285480344),
#  ('construction_year_2012', 0.0014432838074843019),
#  ('region_code_16', 0.0014409250465942775),
#  ('quantity_group_unknown', 0.0014361022224153432),
#  ('quantity_unknown', 0.001433653512876495),
#  ('management_company', 0.0014283404199423293),
#  ('loc_clust_1', 0.0014113938586603604),
#  ('installer_dis', 0.0013983797284619788),
#  ('region_code_17', 0.0013886399383103696),
#  ('region_Shinyanga', 0.0013879444675366855),
#  ('district_code_5', 0.0013862474844585436),
#  ('basin_Lake Victoria', 0.0013530223095874786),
#  ('basin_Wami / Ruvu', 0.0013449353293792006),
#  ('basin_Rufiji', 0.0013403375138828606),
#  ('lga_Rombo', 0.0013385904229637679),
#  ('construction_year_2005', 0.001315994168901024),
#  ('construction_year_1998', 0.0012982566031836406),
#  ('scheme_management_Company', 0.0012770538580645625),
#  ('district_code_6', 0.0012585544633669865),
#  ('source_dam', 0.0012487274735736146),
#  ('construction_year_2002', 0.0012447632939721974),
#  ('loc_clust_16', 0.0012420093694179538),
#  ('construction_year_2003', 0.0012217900395364552),
#  ('payment_pay annually', 0.0012197142933138062),
#  ('loc_clust_12', 0.001216318966535091),
#  ('construction_year_2011', 0.0011934583661694666),
#  ('lga_Kigoma Rural', 0.0011832949194560346),
#  ('region_Arusha', 0.0011770657402988829),
#  ('region_Dodoma', 0.0011748400832054184),
#  ('construction_year_1976', 0.0011618463646321825),
#  ('permit_nan', 0.0011439916875869774),
#  ('installer_ins', 0.0011430802764135417),
#  ('loc_clust_6', 0.0011227609448890964),
#  ('construction_year_1985', 0.0011201107382645091),
#  ('construction_year_1978', 0.0011103222212174016),
#  ('scheme_management_WUA', 0.0011035095296603533),
#  ('region_code_3', 0.0010977965112675073),
#  ('funder_min', 0.0010975093220619426),
#  ('installer_cen', 0.0010946992740411996),
#  ('funder_tas', 0.0010895506761098512),
#  ('installer_wor', 0.0010825775731207906),
#  ('region_code_1', 0.0010825239310013786),
#  ('construction_year_2004', 0.0010821653518493072),
#  ('construction_year_1996', 0.0010534143886604425),
#  ('funder_afr', 0.0010525361825144627),
#  ('funder_fun', 0.0010517678474597505),
#  ('management_parastatal', 0.0010466426507703241),
#  ('lga_Sengerema', 0.0010357416211384306),
#  ('construction_year_1984', 0.001016979423580637),
#  ('funder_uni', 0.001008192102514893),
#  ('management_water board', 0.0010045560357978189),
#  ('funder_rws', 0.0010038137599431821),
#  ('funder_adr', 0.00099940198242158833),
#  ('region_code_15', 0.00099049929477616891),
#  ('management_wua', 0.00098500583432348395),
#  ('region_Kilimanjaro', 0.00098289424262879379),
#  ('lga_Chunya', 0.0009566718408715038),
#  ('construction_year_1997', 0.00095362732972064453),
#  ('lga_Shinyanga Rural', 0.00095140527248419103),
#  ('scheme_management_Parastatal', 0.00093577007626973992),
#  ('region_code_20', 0.00092841699703774788),
#  ('lga_Kondoa', 0.00089999278507422412),
#  ('lga_Mbozi', 0.00089854107096735947),
#  ('region_Mara', 0.00089450579758379954),
#  ('construction_year_1980', 0.00089162971912960635),
#  ('region_Morogoro', 0.00088996388572374989),
#  ('region_code_2', 0.00088348860205605126),
#  ('construction_year_1972', 0.00087653467393189607),
#  ('funder_pri', 0.00087502964607538486),
#  ('basin_Ruvuma / Southern Coast', 0.00087122110228963145),
#  ('funder_dwe', 0.00086106906239808432),
#  ('region_Rukwa', 0.00086020991870713903),
#  ('installer_com', 0.00085464067147364843),
#  ('funder_wat', 0.00084213764174605405),
#  ('region_code_5', 0.00084102421116708046),
#  ('construction_year_1974', 0.00082600002268826513),
#  ('region_Mbeya', 0.00080077849750091669),
#  ('installer_hes', 0.00079322758290582655),
#  ('region_code_19', 0.00079078716934171951),
#  ('subvillage_maje', 0.00079013822479110578),
#  ('region_code_12', 0.00078759526551322738),
#  ('construction_year_1982', 0.00078303329556565022),
#  ('loc_clust_15', 0.00077913465289390421),
#  ('district_code_30', 0.00077185586507535239),
#  ('district_code_53', 0.00076422850265903022),
#  ('region_Mwanza', 0.00075967372210211377),
#  ('district_code_33', 0.00075701369340053931),
#  ('construction_year_1995', 0.00075596893174338024),
#  ('construction_year_1988', 0.00075374319279074395),
#  ('funder_nor', 0.00074612815057053747),
#  ('region_Tanga', 0.00074572821987570334),
#  ('construction_year_1990', 0.00073896837828582671),
#  ('lga_Moshi Rural', 0.00070874452577772949),
#  ('funder_dis', 0.00070448635382079996),
#  ('water_quality_milky', 0.00070211729487920811),
#  ('lga_Ngara', 0.00070205826261635139),
#  ('loc_clust_2', 0.00069980319850675317),
#  ('region_code_4', 0.00069896329205592007),
#  ('district_code_8', 0.00068267221237501129),
#  ('construction_year_1993', 0.0006777925387670095),
#  ('lga_Same', 0.00066271012572973668),
#  ('management_water authority', 0.00066097123319411614),
#  ('construction_year_1970', 0.00066030544174013528),
#  ('lga_Kyela', 0.00065967309616552666),
#  ('subvillage_madu', 0.0006531136181968523),
#  ('construction_year_1994', 0.0006503101673495991),
#  ('payment_other', 0.00063825346660565828),
#  ('lga_Muleba', 0.00063609494680042986),
#  ('region_Pwani', 0.00062450335661577369),
#  ('region_Kagera', 0.00060670385424817577),
#  ('subvillage_nyam', 0.00060518174380714846),
#  ('region_Tabora', 0.00060443310306253597),
#  ('funder_kkk', 0.0005960770007017018),
#  ('installer_kkk', 0.00059357029364419888),
#  ('installer_tcr', 0.00059212932337043378),
#  ('lga_Mpanda', 0.00058677911072325527),
#  ('source_hand dtw', 0.00058308470824272617),
#  ('construction_year_1999', 0.00058161573584937563),
#  ('extraction_type_other - rope pump', 0.00057816013518677853),
#  ('construction_year_2001', 0.00057327140559149472),
#  ('water_quality_salty abandoned', 0.00057263679697876527),
#  ('construction_year_1986', 0.00057079574719999971),
#  ('lga_Kilosa', 0.00056158832937342786),
#  ('subvillage_shul', 0.00055294419950407839),
#  ('lga_Ukerewe', 0.00055091901930874555),
#  ('lga_Rungwe', 0.0005483186344827824),
#  ('lga_Pangani', 0.00054828277332694521),
#  ('scheme_management_Private operator', 0.00054769886182226633),
#  ('lga_Kasulu', 0.00054519688577605392),
#  ('lga_Newala', 0.00054273871765218743),
#  ('lga_Kongwa', 0.00053486879495741367),
#  ('lga_Manyoni', 0.00053206155466214663),
#  ('region_code_14', 0.00052819702451641678),
#  ('installer_vil', 0.0005217690827731959),
#  ('lga_Mvomero', 0.00051592443200647428),
#  ('loc_clust_10', 0.00051491263329065122),
#  ('lga_Mpwapwa', 0.00051292179986352877),
#  ('region_Manyara', 0.00050811717555442992),
#  ('management_other', 0.00050502260942775017),
#  ('lga_Serengeti', 0.00049611975526619729),
#  ('construction_year_1975', 0.00049465237573683546),
#  ('funder_dhv', 0.0004902908016413001),
#  ('installer_tas', 0.00048468561363910416),
#  ('region_Singida', 0.00048304590632120589),
#  ('lga_Siha', 0.00048289762286711415),
#  ('region_code_60', 0.00048285704180783243),
#  ('funder_oxf', 0.00048204166333573134),
#  ('lga_Ruangwa', 0.00048189380670866781),
#  ('region_code_18', 0.0004765146183169026),
#  ('region_code_21', 0.00047404615248049361),
#  ('funder_w.b', 0.00047121897525287686),
#  ('region_code_10', 0.000467831778827479),
#  ('loc_clust_13', 0.00046384666154385866),
#  ('region_code_13', 0.00046319902296802258),
#  ('funder_swe', 0.00045340627109699696),
#  ('installer_dan', 0.00045332896507638607),
#  ('funder_fin', 0.00045077347772437331),
#  ('loc_clust_11', 0.00044958264024798128),
#  ('loc_clust_29', 0.00044893558640421997),
#  ('region_Ruvuma', 0.00044853745667853417),
#  ('subvillage_subv', 0.00044681162953413291),
#  ('subvillage_mwan', 0.00044560581252318763),
#  ('subvillage_nyan', 0.00044288568831211684),
#  ('construction_year_2013', 0.00044172158535479275),
#  ('lga_Geita', 0.00043762179708129768),
#  ('lga_Kibondo', 0.00042560283893750255),
#  ('funder_lga', 0.00042527739320375916),
#  ('construction_year_1992', 0.00042312452748550497),
#  ('loc_clust_0', 0.00042064413069326412),
#  ('funder_wsd', 0.00041604550489834962),
#  ('region_Mtwara', 0.00041341920452626983),
#  ('lga_Kiteto', 0.0004100939960411732),
#  ('funder_tcr', 0.00040880830853388614),
#  ('water_quality_coloured', 0.00040657502040235494),
#  ('lga_Kilolo', 0.00040274226695446845),
#  ('construction_year_1983', 0.00040235681738524161),
#  ('installer_fin', 0.0004019535132852834),
#  ('region_Lindi', 0.00040192981685340553),
#  ('subvillage_mwam', 0.00039865068842018659),
#  ('lga_Njombe', 0.00039861403348565987),
#  ('region_code_6', 0.0003977594048952912),
#  ('construction_year_1991', 0.00039676267575054671),
#  ('lga_Singida Rural', 0.00038750506945133521),
#  ('management_unknown', 0.00038670427938318052),
#  ('lga_Meru', 0.00038525880342380278),
#  ('construction_year_1973', 0.00038405287068384687),
#  ('region_code_90', 0.00038293032431413368),
#  ('funder_kil', 0.00038183802746415336),
#  ('scheme_management_Other', 0.00038173722222615029),
#  ('lga_Mwanga', 0.0003802658801502479),
#  ('loc_clust_19', 0.00037600484385757002),
#  ('construction_year_1981', 0.00037544572382917663),
#  ('lga_Arusha Rural', 0.00037287784430094738),
#  ('subvillage_kati', 0.00037058906776684834),
#  ('funder_adb', 0.00037020891958934669),
#  ('lga_Kwimba', 0.00036894080949680444),
#  ('region_code_80', 0.00036636034651700257),
#  ('loc_clust_14', 0.00036515498087648265),
#  ('district_code_43', 0.00036091715138550779),
#  ('lga_Mkuranga', 0.0003599195474905691),
#  ('subvillage_mwab', 0.00035702822360822917),
#  ('subvillage_nyak', 0.00035570816493424041),
#  ('funder_he', 0.00035369614310024538),
#  ('lga_Korogwe', 0.00035149192447458749),
#  ('funder_isf', 0.00034603460316204277),
#  ('installer_twe', 0.0003442005920839799),
#  ('construction_year_1987', 0.00034384973329584545),
#  ('construction_year_1989', 0.00033783744062186117),
#  ('lga_Uyui', 0.0003371960167469729),
#  ('loc_clust_24', 0.00033591831477821428),
#  ('lga_Bukoba Rural', 0.00033546288159505159),
#  ('lga_Simanjiro', 0.0003338303554810841),
#  ('water_quality_fluoride', 0.000332330649067329),
#  ('lga_Bunda', 0.00033230889506682222),
#  ('loc_clust_27', 0.00032749696524972898),
#  ('lga_Mkinga', 0.00032598817504176671),
#  ('lga_Babati', 0.00032309650888614593),
#  ('lga_Maswa', 0.00032306394414653266),
#  ('lga_Nzega', 0.00032181383217690703),
#  ('subvillage_kiba', 0.00032177955468311174),
#  ('lga_Kishapu', 0.00031879483353644322),
#  ('subvillage_bara', 0.00031834407866993577),
#  ('lga_Ulanga', 0.00031825302781642002),
#  ('lga_Masasi', 0.00031340086741695979),
#  ('extraction_type_india mark iii', 0.00031150808989035037),
#  ('lga_Tunduru', 0.00030974030034928204),
#  ('lga_Musoma Rural', 0.00030970641683756423),
#  ('funder_don', 0.0003054316265385179),
#  ('construction_year_1979', 0.00030347169648267306),
#  ('lga_Hanang', 0.0003019435248707913),
#  ('lga_Karagwe', 0.00029737457676118074),
#  ('construction_year_1967', 0.00029704090227701134),
#  ('lga_Sumbawanga Rural', 0.00029328126228699231),
#  ('funder_ir', 0.00028821902763757256),
#  ('funder_vil', 0.0002881988275300957),
#  ('lga_Kilombero', 0.00028769480684878897),
#  ('lga_Namtumbo', 0.0002876516941622948),
#  ('lga_Mufindi', 0.0002858933809017644),
#  ('installer_wat', 0.00028545587070014376),
#  ('funder_mis', 0.00028431389988088884),
#  ('funder_pla', 0.00028314770276329659),
#  ('installer_lga', 0.00028004747638845105),
#  ('construction_year_1963', 0.00027955974400373874),
#  ('funder_car', 0.00027718641689367232),
#  ('lga_Muheza', 0.0002758460228350585),
#  ('lga_Nkasi', 0.00027567701125482221),
#  ('lga_Dodoma Urban', 0.00026857399125485048),
#  ('lga_Lushoto', 0.00026599051088581669),
#  ('funder_con', 0.00026225094157537491),
#  ('loc_clust_20', 0.00026165955547475243),
#  ('lga_Kisarawe', 0.00026159683945914836),
#  ('loc_clust_3', 0.00026142399701412962),
#  ('lga_Mbarali', 0.00026068938534795329),
#  ('lga_Magu', 0.00025812825253907114),
#  ('funder_ded', 0.00025698756081856902),
#  ('subvillage_mtak', 0.00025591614858820388),
#  ('lga_Bagamoyo', 0.00025446003644472888),
#  ('funder_amr', 0.00025407245315404379),
#  ('funder_un', 0.0002538539180182516),
#  ('lga_Igunga', 0.00025276266169563667),
#  ('funder_jic', 0.00025141481145435867),
#  ('installer_amr', 0.00024770740725223043),
#  ('lga_Ilemela', 0.00024732631525043868),
#  ('funder_com', 0.00024703740613452757),
#  ('funder_wvt', 0.00024326120483344333),
#  ('funder_und', 0.00024258130869293841),
#  ('funder_jai', 0.00024059385382263281),
#  ('lga_Rufiji', 0.0002385302415321091),
#  ('lga_Songea Rural', 0.00023688806438732911),
#  ('funder_go', 0.00023537425800306932),
#  ('loc_clust_18', 0.00023361237118606386),
#  ('extraction_type_other - swn 81', 0.00023170306454893059),
#  ('lga_Misenyi', 0.00022955611700869392),
#  ('subvillage_soko', 0.00022712542058770356),
#  ('loc_clust_17', 0.00022464187382394509),
#  ('lga_Urambo', 0.00022276971972099073),
#  ('lga_Morogoro Rural', 0.00022263697958313942),
#  ('lga_Shinyanga Urban', 0.00021898635576039259),
#  ('funder_rom', 0.00021750059700385678),
#  ('lga_Missungwi', 0.00021666296336830018),
#  ('funder_dh', 0.00021487642950660074),
#  ('lga_Iramba', 0.00021223464708043614),
#  ('funder_rud', 0.00021103732062980021),
#  ('lga_Iringa Rural', 0.00020957036136588387),
#  ('funder_snv', 0.00020705197676326606),
#  ('lga_Monduli', 0.00020432383619343458),
#  ('funder_net', 0.0002028071650786562),
#  ('funder_hsw', 0.00020259539194848031),
#  ('funder_unh', 0.00020089104850734888),
#  ('waterpoint_type_cattle trough', 0.00020083173274913855),
#  ('funder_red', 0.00019996228737413648),
#  ('funder_hif', 0.00019439895837411214),
#  ('lga_Mbinga', 0.00019197400302980162),
#  ('lga_Chamwino', 0.00019149460228315885),
#  ('funder_rc ', 0.00019136013446941839),
#  ('funder_mar', 0.00019071922895506712),
#  ('lga_Rorya', 0.00019055697154765755),
#  ('lga_Mbulu', 0.00019005353579680425),
#  ('lga_Ngorongoro', 0.00018806776005847835),
#  ('loc_clust_23', 0.0001846614697915689),
#  ('loc_clust_25', 0.00018244155319296527),
#  ('subvillage_song', 0.00017941407495933721),
#  ('funder_hal', 0.00017926769649901075),
#  ('lga_Meatu', 0.00017757915562523403),
#  ('district_code_23', 0.00017743334165421903),
#  ('lga_Lindi Rural', 0.00017717634579282558),
#  ('source_other', 0.00017595311764380834),
#  ('lga_Mbeya Rural', 0.00017535040047224332),
#  ('extraction_type_cemo', 0.00017471641420302924),
#  ('lga_Ileje', 0.00017387054919271405),
#  ('installer_wed', 0.00017185223886024252),
#  ('funder_mki', 0.00017095968742025241),
#  ('lga_Tanga', 0.00017086027937982762),
#  ('lga_Mafia', 0.00017040120963453831),
#  ('lga_Chato', 0.00016331581396158686),
#  ('funder_tan', 0.00016291478709822878),
#  ('region_code_8', 0.00016235929823491975),
#  ('lga_Handeni', 0.00016195111402932046),
#  ('subvillage_chan', 0.00016164186557970128),
#  ('funder_kir', 0.00016125354583468215),
#  ('lga_Nachingwea', 0.00016103056617773948),
#  ('funder_wfp', 0.0001596433898976365),
#  ('region_code_7', 0.0001590603608947372),
#  ('management_trust', 0.00015816694190346148),
#  ('loc_clust_22', 0.00015775448914311907),
#  ('funder_hol', 0.00015651391622592336),
#  ('funder_ger', 0.00015511877759167908),
#  ('loc_clust_28', 0.00015108493521290601),
#  ('lga_Biharamulo', 0.00015106170497396004),
#  ('lga_Karatu', 0.00015004503519913532),
#  ('construction_year_1977', 0.00014729087459580949),
#  ('loc_clust_9', 0.00014701955522387241),
#  ('loc_clust_26', 0.00014331139721951512),
#  ('funder_ndr', 0.00014293147771482468),
#  ('construction_year_1971', 0.00013993903778237489),
#  ('lga_Kibaha', 0.00013778783066313585),
#  ('funder_h', 0.00013768831326049709),
#  ('lga_Hai', 0.00013601852294552649),
#  ('subvillage_mtaa', 0.00013494339381691663),
#  ('region_Dar es Salaam', 0.00013331821634725516),
#  ('lga_Kilwa', 0.00013228541817176357),
#  ('funder_kan', 0.00012959497975298457),
#  ('loc_clust_30', 0.00012946577920044532),
#  ('funder_mil', 0.00012686927699360982),
#  ('funder_das', 0.00012662147594395031),
#  ('funder_sol', 0.00012659434724822304),
#  ('lga_Tarime', 0.00012621839068823615),
#  ('loc_clust_21', 0.00012588818766197035),
#  ('region_code_9', 0.00012551294002775281),
#  ('funder_pad', 0.00012529623060378279),
#  ('extraction_type_walimi', 0.0001247096506239177),
#  ('lga_Bahi', 0.00012305858205976033),
#  ('region_code_24', 0.00012285231471412201),
#  ('funder_law', 0.00012210687455397129),
#  ('funder_bsf', 0.00012204316776543755),
#  ('funder_kae', 0.00012108702456121651),
#  ('extraction_type_windmill', 0.00012107906326911665),
#  ('funder_kid', 0.0001200200827661577),
#  ('funder_ida', 0.00011978305789038276),
#  ('district_code_13', 0.00011959874356103612),
#  ('funder_qui', 0.00011868980191300635),
#  ('funder_gtz', 0.00011796916992950891),
#  ('lga_Sumbawanga Urban', 0.00011671272685130864),
#  ('funder_oik', 0.00011660095478709688),
#  ('funder_rur', 0.00011568603620721125),
#  ('region_code_99', 0.00011421056256878968),
#  ('lga_Ilala', 0.00011369488754952488),
#  ('lga_Singida Urban', 0.00011349520432618783),
#  ('funder_nca', 0.00011345773061180116),
#  ('funder_kuw', 0.00011281257700042718),
#  ('lga_Bukombe', 0.00010906591804263552),
#  ('scheme_management_Trust', 0.00010729890769402746),
#  ('funder_lwi', 0.00010715050542774851),
#  ('lga_Mtwara Rural', 0.00010709433062943953),
#  ('funder_aic', 0.00010639658735990843),
#  ('lga_Longido', 0.00010454642026812565),
#  ('funder_no', 0.00010298999063605351),
#  ('basin_nan', 0.0),
#  ('construction_year_nan', 0.0),
#  ('district_code_nan', 0.0),
#  ('extraction_type_other - mkulima/shinyanga', 0.0),
#  ('extraction_type_nan', 0.0),
#  ('funder_nan', 0.0),
#  ('installer_nan', 0.0),
#  ('lga_Nyamagana', 0.0),
#  ('lga_nan', 0.0),
#  ('management_nan', 0.0),
#  ('payment_nan', 0.0),
#  ('quantity_nan', 0.0),
#  ('quantity_group_nan', 0.0),
#  ('region_nan', 0.0),
#  ('region_code_40', 0.0),
#  ('region_code_nan', 0.0),
#  ('scheme_management_None', 0.0),
#  ('source_nan', 0.0),
#  ('subvillage_nan', 0.0),
#  ('water_quality_nan', 0.0),
#  ('waterpoint_type_nan', 0.0),
#  ('loc_clust_nan', 0.0)]

# %% [markdown]
# ## Predict competition data set

# %%
######################
# Prediction for competition
##################################################################

prediction = clf.predict(test_values[features])
prediction_df = pd.DataFrame(prediction, columns=["status_group"])
submission = pd.merge(test_values.id.reset_index()["id"].to_frame(), prediction_df, right_index = True, left_index = True)
submission.head()
submission.to_csv("sub.csv", index = False)
# Out:
#       id    status_group
# 0  50785      functional
# 1  51630      functional
# 2  17168      functional
# 3  45559  non functional
# 4  49871      functional
