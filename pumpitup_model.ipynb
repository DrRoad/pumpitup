# %% [markdown]
# # Pump it Up: Data Mining the Water Table
#
# By: [Ville Heilala](https://heila.la), 2017
#
# Datasource: http://taarifa.org/, http://maji.go.tz/, https://www.drivendata.org
#
# Goal is to predict the operating condition of a waterpoint for each record in the dataset.
#
# ## Model the data

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import sys
# %matplotlib inline

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.6.0 |Anaconda 4.3.1 (64-bit)| (default, Dec 23 2016, 12:22:00)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# Pandas version 0.19.2
# Matplotlib version 2.0.0

# %%
######################
# Read data
##################################################################

train_values = pd.read_csv("/train_values_processed.csv")
test_values = pd.read_csv("/test_values_processed.csv")

# %%
exclude = ("id", "test", "train", "status_group", "num_private", "scheme_name",
           'waterpoint_type_group',
           'quality_group',
           'payment_type',
           'extraction_type_group',
           'extraction_type_class',
           'management_group',
           'source_type',
           'source_class')

# %%
from sklearn.ensemble import RandomForestClassifier

######################
# Select features
##################################################################

features = [col for col in list(train_values) if not col.startswith(exclude)]

######################
# Train model
##################################################################

# Build a forest of trees from the training set
clf = RandomForestClassifier(n_estimators=500, 
                             min_samples_leaf=2, 
                             max_features=0.20, 
                             oob_score=True, 
                             random_state=20).fit(train_values[features],
                                                  train_values["status_group"])

######################
# Evaluate model
##################################################################

print("OOB Error Score: " + str(round(1 - clf.oob_score_, 4)))

# %% [markdown]
# ## Evaluate model

# %%
from sklearn.model_selection import cross_val_score

# Make prediction
predicted = clf.predict(train_values[features])

# Confusion matrix
pd.crosstab(train_values.status_group, predicted, rownames=['Actual'], colnames=['Predicted'])

# Sorted feature importance
fi = sorted(list(zip(train_values[features], clf.feature_importances_)), key=lambda x: str(x[1]), reverse=True)
fi

# Evaluate a score by cross-validation
#scores = cross_val_score(clf, train_values[features], train_values["status_group"], cv=10)
#print("Accuracy: %0.4f (+/- %0.4f)" % (scores.mean(), scores.std() * 2))
# Out:
# Predicted                functional  functional needs repair  non functional
# Actual
# functional                    31537                      182             540
# functional needs repair        1286                     2698             333
# non functional                 1617                      105           21102
# [('funder_ida', 9.9293968618851346e-05),
#  ('funder_no', 9.6841060795652234e-05),
#  ('funder_st', 9.672118385998802e-06),
#  ('funder_twe', 9.6241311703866266e-05),
#  ('region_code_1971', 9.5870294289378499e-05),
#  ('funder_chu', 9.4255557701772199e-05),
#  ('funder_lam', 9.3835209623678914e-05),
#  ('funder_the', 9.3542763544155819e-05),
#  ('funder_ta', 9.2768376165127506e-05),
#  ('lga_Longido', 9.2627442498962337e-05),
#  ('lga_Kilindi', 8.9484572271170297e-05),
#  ('funder_miz', 8.8535145939588872e-07),
#  ('lga_Makete', 8.8497174432104018e-05),
#  ('funder_nat', 8.7920889508381271e-05),
#  ('funder_isl', 8.6259573091860333e-05),
#  ('funder_cef', 8.4464029940762099e-06),
#  ('source_unknown', 8.3123080902120801e-05),
#  ('extraction_type_climax', 8.0883973366533707e-06),
#  ('funder_dmd', 8.0530088738474092e-05),
#  ('funder_coc', 8.0175481037901444e-05),
#  ('lga_Sikonge', 8.0164236565765214e-05),
#  ('scheme_management_SWC', 7.9421850731117087e-05),
#  ('lga_Bukoba Urban', 7.9278461290664651e-05),
#  ('extraction_type_other - play pump', 7.7379121737884766e-05),
#  ('district_code_60', 7.7151760400051702e-05),
#  ('funder_dad', 7.6467868922945869e-05),
#  ('funder_ces', 7.5904357814381975e-05),
#  ('funder_shi', 7.5814275308818375e-05),
#  ('funder_fat', 7.4941100917318487e-05),
#  ('funder_co', 7.3541970948547589e-05),
#  ('funder_jap', 7.0503207599603062e-05),
#  ('district_code_63', 6.9961613191124196e-05),
#  ('funder_los', 6.93903943192236e-06),
#  ('region_code_1969', 6.8762442220220678e-05),
#  ('funder_is', 6.7619118720663364e-05),
#  ('funder_ser', 6.6662182214212096e-05),
#  ('funder_lvi', 6.658915697608958e-05),
#  ('funder_ki', 6.6301004450086839e-05),
#  ('funder_ru', 6.5943081174585095e-05),
#  ('lga_Mtwara Urban', 6.5187258835759464e-05),
#  ('lga_Temeke', 6.4232257557653134e-05),
#  ('installer_ces', 6.3410195828745219e-05),
#  ('funder_sem', 6.2766592500033562e-05),
#  ('lga_Tandahimba', 6.2747748480428706e-05),
#  ('funder_gru', 6.2211758152648888e-05),
#  ('district_code_67', 6.1841864763701022e-06),
#  ('lga_Tabora Urban', 6.1825150157508943e-05),
#  ('region_code_1965', 6.1378560563957854e-06),
#  ('funder_jbg', 6.1052051500383925e-05),
#  ('construction_year_1969', 6.0711531405568145e-05),
#  ('funder_wan', 6.0282440198763789e-05),
#  ('funder_tz ', 5.9766771535165973e-06),
#  ('district_code_0', 5.9618465835127136e-05),
#  ('management_other - school', 5.9205196418451599e-05),
#  ('construction_year_1965', 5.8726578842426138e-06),
#  ('construction_year_1968', 5.788816532499445e-05),
#  ('lga_Morogoro Urban', 5.6514968828836704e-05),
#  ('funder_adp', 5.5838556276138959e-05),
#  ('funder_sha', 5.5819069931208938e-05),
#  ('loc_clust_32', 5.547672026265509e-05),
#  ('region_code_1968', 5.3572765811107807e-05),
#  ('construction_year_1960', 5.3422763916142316e-05),
#  ('funder_pet', 5.3245201720512868e-05),
#  ('funder_tlc', 5.3241235063327053e-05),
#  ('funder_cms', 5.2262095724192043e-05),
#  ('funder_md', 5.1648040603763648e-05),
#  ('lga_Nanyumbu', 5.0682603182414769e-05),
#  ('funder_mdr', 4.9385465951590031e-05),
#  ('funder_sab', 4.8922713963169113e-05),
#  ('funder_eur', 4.8553034274295154e-05),
#  ('region_code_1960', 4.7190034710628896e-05),
#  ('lga_Arusha Urban', 4.670405529681455e-05),
#  ('funder_vwc', 4.6058208796917573e-05),
#  ('lga_Ludewa', 4.5073399387952926e-05),
#  ('funder_rc', 4.4920171458961771e-05),
#  ('funder_rid', 4.4808711897647266e-05),
#  ('funder_kib', 4.3631476432121954e-05),
#  ('lga_Kinondoni', 4.1328932042424612e-05),
#  ('district_code_62', 4.0832802927484975e-05),
#  ('funder_iri', 4.0353015936506798e-05),
#  ('lga_Moshi Urban', 3.9433349400231207e-05),
#  ('funder_ang', 3.7717147388306649e-05),
#  ('funder_dev', 3.7574919767007609e-05),
#  ('funder_mag', 3.6653349185014653e-05),
#  ('funder_ms', 3.643251181621693e-05),
#  ('funder_acr', 3.4853180063154599e-07),
#  ('funder_swi', 3.4736219785008011e-05),
#  ('lga_Liwale', 3.3912032904654739e-05),
#  ('region_code_1962', 3.2921777373082686e-05),
#  ('funder_son', 3.2508260802901378e-05),
#  ('construction_year_1962', 3.238751337534944e-05),
#  ('funder_wua', 3.1600719872441763e-05),
#  ('funder_par', 3.0061271575960859e-05),
#  ('funder_tdf', 2.9939435153568048e-05),
#  ('funder_tar', 2.832829096232784e-05),
#  ('region_code_1964', 2.8142464557396924e-05),
#  ('water_quality_fluoride abandoned', 2.5663037063246402e-06),
#  ('construction_year_1964', 2.4255933143688765e-05),
#  ('lga_Kigoma Urban', 2.4200325011928681e-05),
#  ('funder_gen', 2.4170022781926306e-05),
#  ('funder_muw', 2.3978100639113125e-05),
#  ('funder_mak', 2.3059147345959511e-05),
#  ('construction_year_1961', 2.1349503131059857e-05),
#  ('region_code_1961', 2.1322186974806396e-05),
#  ('lga_Lindi Urban', 2.0231419406774585e-06),
#  ('funder_dfi', 1.9972840991033104e-05),
#  ('funder_fw', 1.9374062683489622e-05),
#  ('funder_tab', 1.9247331038013283e-05),
#  ('funder_kal', 1.742297339466038e-05),
#  ('funder_chi', 1.6522624553707347e-05),
#  ('funder_idc', 1.4769598937243197e-05),
#  ('funder_aba', 1.4371208736101505e-05),
#  ('waterpoint_type_dam', 1.4356150635454798e-05),
#  ('district_code_80', 1.4081561927748127e-05),
#  ('region_code_1966', 1.3605310883996568e-05),
#  ('funder_sod', 1.2580096254404105e-07),
#  ('construction_year_1966', 1.2512477873673211e-05),
#  ('funder_tre', 1.2432132712829496e-05),
#  ('loc_clust_31', 1.1650465873043658e-05),
#  ('funder_caf', 1.1563017805319792e-05),
#  ('lga_Songea Urban', 1.1318392743361898e-05),
#  ('funder_cdt', 1.0231472026102252e-05),
#  ('longitude', 0.084677484023593028),
#  ('latitude', 0.082504327985177928),
#  ('gps_height', 0.073405900607451668),
#  ('quantity_group_dry', 0.063726126730426283),
#  ('quantity_dry', 0.062843872609662982),
#  ('waterpoint_type_other', 0.043547345941042537),
#  ('extraction_type_other', 0.033586759779235378),
#  ('population', 0.030986672081108398),
#  ('amount_tsh', 0.022079220295579197),
#  ('quantity_group_enough', 0.014274979946121822),
#  ('quantity_enough', 0.013163348490708026),
#  ('payment_never pay', 0.011295109518487226),
#  ('waterpoint_type_communal standpipe multiple', 0.01122772113512146),
#  ('waterpoint_type_communal standpipe', 0.010794604601701919),
#  ('funder_gov', 0.0087512153093742637),
#  ('extraction_type_gravity', 0.0076250093144330363),
#  ('source_spring', 0.0067279325840555208),
#  ('waterpoint_type_hand pump', 0.0067264295872854754),
#  ('quantity_group_insufficient', 0.0062762316339552105),
#  ('extraction_type_nira/tanira', 0.0059961230633756198),
#  ('quantity_insufficient', 0.0056974269186464681),
#  ('installer_dwe', 0.0055998068898192657),
#  ('management_vwc', 0.0055977261660476911),
#  ('installer_installer_oth', 0.00513500176138737),
#  ('region_Iringa', 0.0046546114958850296),
#  ('source_machine dbh', 0.004603044598777817),
#  ('source_shallow well', 0.0043679568120287898),
#  ('payment_pay per bucket', 0.0042451196836426081),
#  ('source_rainwater harvesting', 0.0041446086124780658),
#  ('subvillage_subvillage_oth', 0.0040203340047812279),
#  ('public_meeting_True', 0.0039402124421378092),
#  ('permit_True', 0.0039006735576763759),
#  ('water_quality_unknown', 0.0038988310380164669),
#  ('scheme_management_VWC', 0.0038941320474638898),
#  ('extraction_type_ksb', 0.0038852249258585813),
#  ('water_quality_soft', 0.0038485142163171451),
#  ('payment_unknown', 0.0038148283990317965),
#  ('quantity_group_seasonal', 0.0037696514803708539),
#  ('permit_False', 0.0037594875333884629),
#  ('public_meeting_False', 0.0037036281965590542),
#  ('source_river', 0.0036042412632814533),
#  ('installer_rwe', 0.0034842269885340194),
#  ('funder_funder_oth', 0.0033869069882612652),
#  ('quantity_seasonal', 0.00317110280512497),
#  ('loc_clust_-1', 0.0030340117631029576),
#  ('payment_pay monthly', 0.0030045492178608535),
#  ('district_code_1', 0.0029475571136993598),
#  ('district_code_3', 0.0028276360834758396),
#  ('lga_Bariadi', 0.0026982389506777357),
#  ('district_code_2', 0.0026845004454801838),
#  ('loc_clust_7', 0.0026316404671217078),
#  ('extraction_type_swn 80', 0.0026170571252630451),
#  ('basin_Lake Nyasa', 0.0026150739743090331),
#  ('extraction_type_submersible', 0.0025690466727345215),
#  ('funder_wor', 0.002466216185971841),
#  ('installer_gov', 0.002461759776347498),
#  ('basin_Internal', 0.002363865882539382),
#  ('water_quality_salty', 0.0023346596918314868),
#  ('region_code_0', 0.0022929174467536725),
#  ('district_code_4', 0.0022691300894051112),
#  ('extraction_type_mono', 0.0022564424989058897),
#  ('construction_year_0', 0.0021608124355858233),
#  ('basin_Lake Rukwa', 0.0021132211365442991),
#  ('funder_dws', 0.0021090082693464131),
#  ('scheme_management_WUG', 0.0019998537796485955),
#  ('public_meeting_nan', 0.0019892413312986553),
#  ('loc_clust_8', 0.0019648051615276008),
#  ('management_private operator', 0.0019550162748479976),
#  ('region_code_2010', 0.0019466823081021392),
#  ('construction_year_2010', 0.0019416181196132848),
#  ('funder_hes', 0.0018899122714861518),
#  ('basin_Lake Tanganyika', 0.0018642428380651339),
#  ('scheme_management_nan', 0.0018499178203166588),
#  ('lga_Kahama', 0.0017703931037356823),
#  ('region_Kigoma', 0.0017597512529533973),
#  ('waterpoint_type_improved spring', 0.0017416613099573615),
#  ('source_lake', 0.0017273663234497038),
#  ('management_wug', 0.0017204669032976458),
#  ('scheme_management_Water authority', 0.0016983624198109273),
#  ('region_Shinyanga', 0.0016966435155013968),
#  ('payment_pay when scheme fails', 0.0016849570072533361),
#  ('extraction_type_india mark ii', 0.0016257838491569754),
#  ('loc_clust_5', 0.0015805506876070304),
#  ('basin_Pangani', 0.001558482142866713),
#  ('loc_clust_4', 0.0015525870495743839),
#  ('quantity_unknown', 0.0015357539820364994),
#  ('scheme_management_Water Board', 0.0015157515159312791),
#  ('basin_Lake Victoria', 0.0014909780900745084),
#  ('quantity_group_unknown', 0.001488722275745788),
#  ('district_code_7', 0.00148337721617127),
#  ('basin_Rufiji', 0.0014695800213997228),
#  ('region_Dodoma', 0.0014599618345662137),
#  ('extraction_type_afridev', 0.0014534296216253883),
#  ('funder_dan', 0.001443261337916777),
#  ('loc_clust_1', 0.0014425572543351592),
#  ('installer_dis', 0.0014381823045045629),
#  ('management_company', 0.0014368585424290781),
#  ('construction_year_2009', 0.001430854019876322),
#  ('region_code_2008', 0.0014298087594159369),
#  ('construction_year_2008', 0.0014028456818150473),
#  ('district_code_5', 0.00140232119890563),
#  ('region_code_2009', 0.0013853667606830058),
#  ('district_code_6', 0.0013724057711646635),
#  ('region_Arusha', 0.0013684279674107773),
#  ('basin_Wami / Ruvu', 0.0013646029478453759),
#  ('lga_Kigoma Rural', 0.0013339593901089072),
#  ('lga_Rombo', 0.0013055503450837471),
#  ('region_code_2006', 0.0012964410839864326),
#  ('source_dam', 0.0012916849992044303),
#  ('loc_clust_6', 0.0012837718080048184),
#  ('construction_year_2006', 0.0012826084401667062),
#  ('payment_pay annually', 0.0012731716815373175),
#  ('loc_clust_12', 0.0012413690006591851),
#  ('loc_clust_16', 0.0012381881279370044),
#  ('scheme_management_Company', 0.0012219055285350206),
#  ('region_Kilimanjaro', 0.0012065300037330114),
#  ('region_code_2007', 0.0012038830256559884),
#  ('permit_nan', 0.001193983817484391),
#  ('construction_year_2007', 0.0011901368153817541),
#  ('region_Rukwa', 0.0011789126249071122),
#  ('installer_ins', 0.0011385178479154097),
#  ('installer_wor', 0.0011109934694091756),
#  ('construction_year_2000', 0.0011060691097583731),
#  ('region_code_2000', 0.0011013368233939581),
#  ('installer_cen', 0.001084098513704393),
#  ('funder_fun', 0.0010817506968737987),
#  ('scheme_management_WUA', 0.0010507128036602398),
#  ('funder_rws', 0.0010398317517263203),
#  ('region_code_2012', 0.001033581239951831),
#  ('lga_Sengerema', 0.0010330934917978135),
#  ('funder_min', 0.0010328459611624811),
#  ('funder_afr', 0.001029466370329028),
#  ('region_Mara', 0.0010258609270668265),
#  ('management_parastatal', 0.0010228925746689455),
#  ('construction_year_2012', 0.0010213330100708657),
#  ('funder_tas', 0.0010193180890641018),
#  ('region_Morogoro', 0.0010129785903558299),
#  ('management_water board', 0.0010077003945654476),
#  ('lga_Kondoa', 0.00099816722803906517),
#  ('region_code_2005', 0.00099179553957049176),
#  ('lga_Chunya', 0.00097939496311081654),
#  ('region_Mwanza', 0.0009636730316963058),
#  ('lga_Shinyanga Rural', 0.00096256566673751424),
#  ('region_Mbeya', 0.00096020265958349064),
#  ('scheme_management_Parastatal', 0.00095066217474742336),
#  ('construction_year_2005', 0.00094649463295365995),
#  ('funder_adr', 0.00094435823110558038),
#  ('region_code_2011', 0.00092139894904618846),
#  ('construction_year_2011', 0.00091653213516594708),
#  ('construction_year_2003', 0.00091507904501970016),
#  ('basin_Ruvuma / Southern Coast', 0.00091151125630488589),
#  ('region_Tanga', 0.00090998216653099704),
#  ('management_wua', 0.00090606566195667009),
#  ('construction_year_1998', 0.00090275009749388733),
#  ('region_code_1998', 0.00089465265445232741),
#  ('region_code_2002', 0.00089343246706270686),
#  ('funder_uni', 0.00088710827593852361),
#  ('construction_year_2002', 0.00088232579223574282),
#  ('region_code_2003', 0.00088079619586907323),
#  ('funder_wat', 0.00087504413520483643),
#  ('lga_Mbozi', 0.00086816539820345378),
#  ('installer_com', 0.00086518333116544853),
#  ('construction_year_1976', 0.00084804049765262505),
#  ('installer_hes', 0.0008374332375233899),
#  ('construction_year_1985', 0.00082888224720427633),
#  ('funder_dwe', 0.00082606990793740562),
#  ('region_code_1976', 0.0008242944633532485),
#  ('region_code_1978', 0.00081789842884820072),
#  ('funder_pri', 0.00080591916805373834),
#  ('loc_clust_15', 0.0008049275107309638),
#  ('construction_year_2004', 0.00080279514817725749),
#  ('construction_year_1978', 0.00079979578463880115),
#  ('region_code_2004', 0.00079734637548905553),
#  ('loc_clust_2', 0.00078934270892570672),
#  ('region_code_1996', 0.000784441938877564),
#  ('region_code_1985', 0.00078370361914282562),
#  ('district_code_33', 0.00078045848972526288),
#  ('construction_year_1996', 0.00077562367234785482),
#  ('district_code_8', 0.00077174287905587319),
#  ('subvillage_maje', 0.00076868001058803402),
#  ('water_quality_milky', 0.00076810600834678155),
#  ('construction_year_1984', 0.00074480230984397342),
#  ('region_code_1984', 0.00074156439683868876),
#  ('lga_Rungwe', 0.00073898322366297391),
#  ('construction_year_1972', 0.00073537448585119913),
#  ('lga_Same', 0.00071374744229328146),
#  ('lga_Moshi Rural', 0.00070869514218016322),
#  ('lga_Ngara', 0.0007081469030786662),
#  ('funder_dis', 0.00069524184480034674),
#  ('region_code_1972', 0.00069113157808032677),
#  ('construction_year_1997', 0.00069107485661652518),
#  ('region_code_1997', 0.00068230428375113186),
#  ('region_Pwani', 0.00068134739508079513),
#  ('region_Kagera', 0.00068071141885487707),
#  ('district_code_53', 0.00067576569184311821),
#  ('region_Tabora', 0.00066005907785681795),
#  ('construction_year_1980', 0.0006576021633833796),
#  ('region_code_1974', 0.00065390454913155931),
#  ('funder_nor', 0.00065101864902256134),
#  ('region_code_1980', 0.00064606439731692471),
#  ('subvillage_madu', 0.00063196102014276756),
#  ('region_Singida', 0.00062539094277320431),
#  ('management_water authority', 0.00062082493710250634),
#  ('installer_tcr', 0.00061877076445824078),
#  ('district_code_30', 0.00061613769276760196),
#  ('construction_year_1974', 0.00061596529688873615),
#  ('payment_other', 0.00061249148775148758),
#  ('construction_year_1995', 0.00060677194002121992),
#  ('subvillage_nyam', 0.00060412941764977979),
#  ('lga_Muleba', 0.00060374628609926218),
#  ('region_code_1995', 0.00060190191734448429),
#  ('source_hand dtw', 0.00059351262580803748),
#  ('installer_kkk', 0.00059220566678064909),
#  ('lga_Mvomero', 0.00058916452464989198),
#  ('funder_kkk', 0.00058234508821355707),
#  ('lga_Njombe', 0.00057635580977890676),
#  ('loc_clust_10', 0.00057405794092951908),
#  ('lga_Kilosa', 0.00057047828560139564),
#  ('region_code_1988', 0.00056935011597658678),
#  ('region_code_1982', 0.00056745489029478224),
#  ('construction_year_1990', 0.00056507090798063608),
#  ('region_Manyara', 0.00056392666440688148),
#  ('construction_year_1982', 0.00056387140751527247),
#  ('construction_year_1988', 0.00056313501253064642),
#  ('installer_vil', 0.00056189809289883394),
#  ('region_code_1990', 0.00055530759592974609),
#  ('lga_Pangani', 0.00055378571057375218),
#  ('lga_Mpanda', 0.00055261894494157047),
#  ('lga_Manyoni', 0.00055119340139637692),
#  ('water_quality_salty abandoned', 0.00055007463353571998),
#  ('lga_Newala', 0.00054906329012452035),
#  ('loc_clust_11', 0.00054873882019386183),
#  ('scheme_management_Private operator', 0.00054480122446684456),
#  ('lga_Kyela', 0.00053993243318268397),
#  ('subvillage_shul', 0.00053906720328549364),
#  ('extraction_type_other - rope pump', 0.0005318786243359259),
#  ('lga_Serengeti', 0.00052722945323829958),
#  ('lga_Kongwa', 0.00052411549857080781),
#  ('lga_Mpwapwa', 0.00051620841874969094),
#  ('management_other', 0.00051388520323579652),
#  ('construction_year_1994', 0.00050115307589924387),
#  ('region_code_1993', 0.00049914551655298354),
#  ('lga_Kasulu', 0.00049746748244293112),
#  ('region_code_1994', 0.00049668175333728839),
#  ('subvillage_subv', 0.00049444719206937513),
#  ('lga_Ukerewe', 0.00049028401994493374),
#  ('construction_year_1993', 0.00048519877242569637),
#  ('region_Lindi', 0.00048234019587139516),
#  ('construction_year_1970', 0.0004791222552342676),
#  ('funder_swe', 0.0004770022478903624),
#  ('funder_oxf', 0.00047144278201108098),
#  ('loc_clust_0', 0.00046705965977358481),
#  ('lga_Geita', 0.00046591360415650898),
#  ('region_Mtwara', 0.00046586118092928368),
#  ('region_code_1970', 0.00046100304247209683),
#  ('installer_tas', 0.00045894320477531326),
#  ('subvillage_nyan', 0.00045714878173836598),
#  ('loc_clust_29', 0.00045643060265928258),
#  ('lga_Ruangwa', 0.00045465966741627773),
#  ('loc_clust_13', 0.00045338081288564592),
#  ('lga_Kibondo', 0.00044746165981397225),
#  ('region_Ruvuma', 0.00044444711267917935),
#  ('funder_w.b', 0.00044418670396241728),
#  ('funder_dhv', 0.00044119956769994156),
#  ('subvillage_mwan', 0.00043665384514525864),
#  ('funder_fin', 0.00043082626165128997),
#  ('funder_lga', 0.00043040999082770946),
#  ('funder_tcr', 0.00043013943456258401),
#  ('construction_year_2001', 0.00042667791189244814),
#  ('installer_dan', 0.00042519805318592783),
#  ('lga_Kiteto', 0.00042461612412295947),
#  ('region_code_2001', 0.00041972393966182306),
#  ('lga_Siha', 0.00041900645759148297),
#  ('lga_Arusha Rural', 0.0004175163046572275),
#  ('construction_year_1999', 0.00041567066194938683),
#  ('lga_Meru', 0.00041521715014853749),
#  ('construction_year_1986', 0.00041514225483430922),
#  ('region_code_1986', 0.00041510661213291466),
#  ('region_code_1999', 0.00041479005156759146),
#  ('loc_clust_19', 0.00041117565503967507),
#  ('funder_wsd', 0.00040842991939706502),
#  ('water_quality_coloured', 0.00039468154880861479),
#  ('subvillage_mwam', 0.00038920539949605863),
#  ('lga_Kwimba', 0.00038689823986686156),
#  ('subvillage_bara', 0.00038459535425900836),
#  ('lga_Uyui', 0.00038381148296829688),
#  ('construction_year_1975', 0.00038015195739037874),
#  ('installer_fin', 0.00037859873138794994),
#  ('scheme_management_Other', 0.00037689419708711942),
#  ('loc_clust_24', 0.00037667669517791133),
#  ('lga_Mwanga', 0.00037568258947420432),
#  ('lga_Singida Rural', 0.00037523420814039902),
#  ('district_code_43', 0.00037164180638396972),
#  ('management_unknown', 0.0003704927072767556),
#  ('subvillage_mwab', 0.00036500050166539681),
#  ('lga_Bukoba Rural', 0.00036495710859902285),
#  ('lga_Tunduru', 0.00036348511093184128),
#  ('lga_Korogwe', 0.00036186933177627265),
#  ('subvillage_nyak', 0.00036127581040814753),
#  ('construction_year_2013', 0.00036108735165287425),
#  ('funder_kil', 0.00036095196712066397),
#  ('lga_Sumbawanga Rural', 0.00035289234607631696),
#  ('funder_he', 0.00035189052151527714),
#  ('lga_Muheza', 0.00035073071352401504),
#  ('funder_adb', 0.00034832003004696454),
#  ('region_code_1975', 0.00034774307797372819),
#  ('region_code_2013', 0.00034693884793225943),
#  ('lga_Kilolo', 0.00034686607283458437),
#  ('subvillage_kati', 0.00034540611085761349),
#  ('lga_Mkuranga', 0.00034488644039585648),
#  ('lga_Bunda', 0.00033961759237347982),
#  ('lga_Simanjiro', 0.00033644267719259193),
#  ('lga_Nzega', 0.00033500927547687524),
#  ('lga_Musoma Rural', 0.00033427476089802007),
#  ('lga_Babati', 0.00033178965639484286),
#  ('loc_clust_14', 0.0003288395629934394),
#  ('construction_year_1992', 0.0003284607385456594),
#  ('lga_Maswa', 0.00032833936867940675),
#  ('region_code_1992', 0.0003260875127491665),
#  ('funder_isf', 0.0003257786520684635),
#  ('lga_Kishapu', 0.00032517712349003662),
#  ('extraction_type_india mark iii', 0.00032424568904556949),
#  ('lga_Ulanga', 0.00032188584515604248),
#  ('water_quality_fluoride', 0.00031594763833425217),
#  ('installer_twe', 0.00031327149186123393),
#  ('installer_lga', 0.00031304665897693301),
#  ('region_code_1991', 0.00031196804809732623),
#  ('lga_Kilombero', 0.00031104305767235273),
#  ('construction_year_1991', 0.00030995355822007636),
#  ('funder_don', 0.00030683989088523363),
#  ('construction_year_1983', 0.00030621856281279038),
#  ('lga_Masasi', 0.00030584091008627168),
#  ('lga_Lushoto', 0.00030480383337004065),
#  ('lga_Mkinga', 0.00030264395979856512),
#  ('loc_clust_3', 0.00030037655310839506),
#  ('region_code_1983', 0.00029894890544042104),
#  ('funder_vil', 0.00029863983085229209),
#  ('subvillage_kiba', 0.00029570213780019937),
#  ('lga_Mbarali', 0.00029535403340413363),
#  ('lga_Karagwe', 0.00029271569014493982),
#  ('loc_clust_27', 0.00029071304058058035),
#  ('funder_pla', 0.00028616980202614381),
#  ('installer_wat', 0.00028403879547913869),
#  ('lga_Dodoma Urban', 0.00028265469040249339),
#  ('lga_Hanang', 0.00028095438597971025),
#  ('lga_Bagamoyo', 0.00027989958420994015),
#  ('funder_car', 0.00027892970423339298),
#  ('lga_Mufindi', 0.00027821713977645683),
#  ('lga_Iringa Rural', 0.00027230130071158115),
#  ('loc_clust_18', 0.00027195526929493189),
#  ('funder_ir', 0.00026748593989860088),
#  ('funder_con', 0.00026577908994933043),
#  ('lga_Nkasi', 0.00026552143533242431),
#  ('lga_Magu', 0.00026453040542247816),
#  ('lga_Namtumbo', 0.00026424628998722368),
#  ('installer_amr', 0.000263788439593683),
#  ('region_code_1981', 0.0002636333892585806),
#  ('lga_Kisarawe', 0.00026340131954752507),
#  ('construction_year_1979', 0.00026311805914885428),
#  ('construction_year_1989', 0.00025996469884860383),
#  ('lga_Igunga', 0.00025989849567506197),
#  ('funder_mis', 0.00025666547917282392),
#  ('loc_clust_20', 0.00025660778862124015),
#  ('funder_wvt', 0.00025489606425855991),
#  ('funder_und', 0.00025264773286336997),
#  ('funder_jic', 0.00025237973682724375),
#  ('lga_Rufiji', 0.00025070573136648251),
#  ('funder_amr', 0.00025016047628423496),
#  ('lga_Ilemela', 0.00024973409491971319),
#  ('construction_year_1973', 0.00024928811653280295),
#  ('funder_ded', 0.00024808040527928959),
#  ('lga_Misenyi', 0.00024742555896665731),
#  ('funder_com', 0.0002464404451982974),
#  ('region_code_1987', 0.00024626603122925039),
#  ('construction_year_1981', 0.00024580057339574084),
#  ('funder_un', 0.0002435416939949912),
#  ('region_code_1989', 0.00024128097465159732),
#  ('lga_Shinyanga Urban', 0.00024060091781077318),
#  ('region_code_1973', 0.00023985811675430308),
#  ('lga_Morogoro Rural', 0.00023862251332338661),
#  ('construction_year_1967', 0.00023526271924241698),
#  ('construction_year_1987', 0.00023468585760222978),
#  ('lga_Iramba', 0.00023004559324533975),
#  ('loc_clust_17', 0.00022880133910343193),
#  ('lga_Nachingwea', 0.00022860664191449439),
#  ('lga_Missungwi', 0.00022828945252794617),
#  ('region_code_1967', 0.00022722737314925592),
#  ('subvillage_soko', 0.0002267085157878273),
#  ('extraction_type_other - swn 81', 0.00022664137979336486),
#  ('lga_Urambo', 0.00022638791622082882),
#  ('funder_rom', 0.00021935340277855255),
#  ('lga_Songea Rural', 0.00021640270703168448),
#  ('region_code_1979', 0.00021542106867063971),
#  ('waterpoint_type_cattle trough', 0.00021442740338447903),
#  ('funder_rud', 0.00020955102845812351),
#  ('subvillage_mtak', 0.00020885689518115641),
#  ('lga_Ngorongoro', 0.00020788003474917074),
#  ('funder_hif', 0.00020703429267295633),
#  ('funder_hsw', 0.00020680525664128001),
#  ('lga_Lindi Rural', 0.0002029599407040579),
#  ('funder_jai', 0.00020252173862521963),
#  ('funder_go', 0.00020084363574059407),
#  ('lga_Rorya', 0.0002006737176031519),
#  ('funder_unh', 0.00019881332332115855),
#  ('funder_dh', 0.00019601079307159517),
#  ('lga_Meatu', 0.00019588026575829783),
#  ('loc_clust_25', 0.00019568572204678797),
#  ('funder_net', 0.00019568494156659268),
#  ('lga_Chato', 0.00019422728853677468),
#  ('region_code_1963', 0.00019065250153667366),
#  ('funder_red', 0.00018972393336047115),
#  ('lga_Chamwino', 0.00018951973807083419),
#  ('loc_clust_23', 0.00018938433675323282),
#  ('lga_Mbinga', 0.00018846368602260213),
#  ('funder_mar', 0.00018716381360029687),
#  ('lga_Monduli', 0.00018617620345181277),
#  ('construction_year_1963', 0.00018525418885183964),
#  ('funder_snv', 0.00018167102331460898),
#  ('source_other', 0.00018030617570889931),
#  ('subvillage_song', 0.00017958196366769377),
#  ('lga_Mbulu', 0.00017860145706054864),
#  ('region_Dar es Salaam', 0.00017838095679265011),
#  ('lga_Handeni', 0.00017834394690044558),
#  ('funder_rc ', 0.00017777719666383306),
#  ('installer_wed', 0.00017754188037873432),
#  ('funder_hal', 0.00017691502339455009),
#  ('lga_Mafia', 0.00017616495703398215),
#  ('district_code_23', 0.00017291687055761494),
#  ('subvillage_chan', 0.00016946976962238324),
#  ('lga_Tanga', 0.00016829618733609555),
#  ('lga_Biharamulo', 0.00016604828177348195),
#  ('funder_hol', 0.00016286875435500119),
#  ('lga_Mbeya Rural', 0.00015819376118442733),
#  ('loc_clust_22', 0.00015811324744974655),
#  ('loc_clust_28', 0.00015693794238582896),
#  ('extraction_type_cemo', 0.00015584656185308973),
#  ('funder_mki', 0.00015372152305056385),
#  ('funder_kir', 0.00015336292469998625),
#  ('lga_Hai', 0.00015308147480659943),
#  ('funder_tan', 0.000152701615221863),
#  ('lga_Tarime', 0.0001481534153357971),
#  ('funder_wfp', 0.00014777753427318001),
#  ('lga_Kibaha', 0.00014763967350794579),
#  ('loc_clust_9', 0.0001475516436289849),
#  ('lga_Bahi', 0.00014544659114028701),
#  ('lga_Ileje', 0.00014346728808379923),
#  ('loc_clust_26', 0.00014305923670738906),
#  ('funder_ndr', 0.00014200886652180581),
#  ('lga_Ilala', 0.00014198516516923161),
#  ('funder_h', 0.00014068970067506923),
#  ('management_trust', 0.00013890668944189659),
#  ('funder_oik', 0.00013223345512714733),
#  ('subvillage_mtaa', 0.00013206546619087746),
#  ('funder_ger', 0.00013147684782658506),
#  ('district_code_13', 0.00013036277384507951),
#  ('funder_das', 0.00012948383318512992),
#  ('lga_Mtwara Rural', 0.00012841635425365444),
#  ('loc_clust_30', 0.00012647280468703565),
#  ('region_code_1977', 0.0001260975339463918),
#  ('lga_Kilwa', 0.00012483576868619996),
#  ('funder_bsf', 0.0001241328400252647),
#  ('lga_Bukombe', 0.0001239664766169729),
#  ('funder_kae', 0.00012365587677608879),
#  ('funder_mil', 0.00012016393925614182),
#  ('construction_year_1977', 0.00011952772420519157),
#  ('funder_kan', 0.00011875484751334765),
#  ('lga_Karatu', 0.000117725089330419),
#  ('funder_lwi', 0.00011772370474811717),
#  ('funder_kuw', 0.00011470537516246013),
#  ('lga_Singida Urban', 0.00011399278104010325),
#  ('funder_pad', 0.00011393653039998515),
#  ('funder_law', 0.00011279478387833715),
#  ('extraction_type_walimi', 0.00011180844172673127),
#  ('funder_aic', 0.00011117872727551374),
#  ('funder_gtz', 0.0001103460505665918),
#  ('funder_nca', 0.00010955537406484251),
#  ('funder_rur', 0.00010945753235880505),
#  ('extraction_type_windmill', 0.00010915644900285367),
#  ('lga_Sumbawanga Urban', 0.00010895126428338773),
#  ('scheme_management_Trust', 0.0001074153905599632),
#  ('funder_qui', 0.00010687141118739942),
#  ('funder_sol', 0.0001055145781557353),
#  ('funder_kid', 0.00010481119395682679),
#  ('loc_clust_21', 0.00010216828788356444),
#  ('construction_year_1971', 0.00010030372539302153)]

# %% [markdown]
# ## Predict competition data set

# %%
######################
# Prediction for competition
##################################################################

prediction = clf.predict(test_values[features])
prediction_df = pd.DataFrame(prediction, columns=["status_group"])
submission = pd.merge(test_values.id.reset_index()["id"].to_frame(), prediction_df, right_index = True, left_index = True)
submission.head()
submission.to_csv("sub.csv", index = False)
# Out:
#       id    status_group
# 0  50785  non functional
# 1  51630      functional
# 2  17168      functional
# 3  45559  non functional
# 4  49871      functional
